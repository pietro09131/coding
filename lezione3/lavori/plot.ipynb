# %%
# importa la sottolibreria e chiamala plt
import matplotlib.pyplot as plt 
import numpy as np

x = np.linspace(-2, 5, 1000)
y = x **2

plt.plot(x, y)
plt.title("La parabola")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')
